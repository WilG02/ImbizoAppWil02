# %% [markdown]
# <a href="https://colab.research.google.com/github/WilG02/ImbizoAppWil02/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import random
import os

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285397 sha256=04bcc607a3e07c6faed80ea9efa3b1b9d2b5218f8a28fd30f99e6032305b1c5c
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.sql import SQLContext
from pyspark.sql.functions import mean, col, split, col, regexp_extract, when, lit
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import QuantileDiscretizer

# %%
spark = SparkSession.builder.appName('recommender_system').getOrCreate()

# %%
from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-fd3a19d2-5ff4-40a3-b1c7-95b2a059b671" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd3a19d2-5ff4-40a3-b1c7-95b2a059b671">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

df = spark.read.csv('movie_ratings_df.csv', header=True, inferSchema= True)
df.count()
# Out:
# 100000

# %%
df.describe()
# Out:
# DataFrame[summary: string, userId: string, title: string, rating: string]

# %%
df.head()
# Out:
# Row(userId=196, title='Kolya (1996)', rating=3)

# %%
df
# Out:
# DataFrame[userId: int, title: string, rating: int]

# %%
df.limit(10).toPandas()
# Out:
#    userId         title  rating
# 0     196  Kolya (1996)       3
# 1      63  Kolya (1996)       3
# 2     226  Kolya (1996)       5
# 3     154  Kolya (1996)       3
# 4     306  Kolya (1996)       5
# 5     296  Kolya (1996)       4
# 6      34  Kolya (1996)       5
# 7     271  Kolya (1996)       4
# 8     201  Kolya (1996)       4
# 9     209  Kolya (1996)       4

# %%
df.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- rating: integer (nullable = true)

# %%
from pyspark.ml.feature import StringIndexer, IndexToString
stringIndexer = StringIndexer(inputCol='title', outputCol='title_new')

model = stringIndexer.fit(df)

indexed = model.transform(df)

indexed.limit(5).toPandas()
# Out:
#    userId         title  rating  title_new
# 0     196  Kolya (1996)       3      287.0
# 1      63  Kolya (1996)       3      287.0
# 2     226  Kolya (1996)       5      287.0
# 3     154  Kolya (1996)       3      287.0
# 4     306  Kolya (1996)       5      287.0

# %%
train, test = indexed.randomSplit([0.75, 0.25])

from pyspark.ml.recommendation import ALS

rec = ALS(maxIter=10,
          regParam=0.01,
          userCol='userId',
          itemCol='title_new',
          ratingCol='rating',
          nonnegative=True,
          coldStartStrategy='drop')

rec_model = rec.fit(train)

predicted_ratings = rec_model.transform(test)
predicted_ratings.limit(5).toPandas()
# Out:
#    userId                                              title  rating  \
# 0     148                                Blade Runner (1982)       5
# 1     148  Dr. Strangelove or: How I Learned to Stop Worr...       5
# 2     148                                       Dumbo (1941)       4
# 3     148                              Godfather, The (1972)       1
# 4     148                          Gone with the Wind (1939)       5
#
#    title_new  prediction
# 0       52.0    4.590704
# 1      123.0    4.372269
# 2      271.0    2.328451
# 3       11.0    4.830822
# 4      162.0    2.978431

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator_rmse = RegressionEvaluator(metricName='rmse',
                                predictionCol='prediction',
                                labelCol='rating')
print("RMSE:",evaluator_rmse.evaluate(predicted_ratings))

evaluator_r2 = RegressionEvaluator(metricName='r2',
                                predictionCol='prediction',
                                labelCol='rating')
print("R^2:",evaluator_r2.evaluate(predicted_ratings))
# Out:
# RMSE: 1.0209974283340257
# R^2: 0.17613983891853158

# %%
from pyspark.sql.functions import col, lit

unique_movies = indexed.select('title_new').distinct()

def top_movies(user_id, n):
    """Get the top n movies for the user_id"""
    a = unique_movies.alias('a')

    watched_movies = indexed.filter(indexed['userId'] == user_id).select('title_new')

    b = watched_movies.alias('b')

    total_movies = a.join(b, a.title_new == b.title_new, how='left')
#     print(total_movies.limit(10).toPandas())

    remaining_movies = total_movies.where(col('b.title_new').isNull()).select(a.title_new).distinct()

    remaining_movies = remaining_movies.withColumn('userId',  lit(int(user_id)))
#     print(remaining_movies.limit(10).toPandas())

    recommendations = rec_model.transform(remaining_movies).orderBy('prediction', ascending=False).limit(n)

    movie_title = IndexToString(inputCol='title_new', outputCol='title', labels=model.labels)
    final_rec = movie_title.transform(recommendations)

    return final_rec.show(n, False)
